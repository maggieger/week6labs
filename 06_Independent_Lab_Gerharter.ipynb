# %% [markdown]
# **Week 6 Independent Lab:**
#
# # Student Management System👩🏼‍🎓
#
# Author: Magdalena Gerharter, BSc
# Course: BGEN 632 Graduate Introduction to Python
# Term: Spring 2025
# Date: April 2, 2025

# %% [markdown]
# ### Set up lists/variables

# %%
first_names = ["Carmen",
               "Sydney",
               "Neil",
               "Marcus"]
last_names = ["Berzatto",
              "Adamu",
              "Fak",
              "Brooks"]
majors = ["Anthropology",
         "History",
         "Biology",
         "Forestry"]
gpas = [3.7,
        3.5,
        3.0,
        3.9]
academic_violations = ["copying homework",
                       "cheating on exam",
                       "plagiarism",
                       "cheating on quiz",
                       "writing paper for another student"]
student_violations = ["none",
                      "none",
                      "none",
                      "none"]

student_added = False  #keeps track of whether a student has been added

# %% [markdown]
# # Create Nested Loop
#
# LOOP WHILE TRUE
#
# Create a menu system
# Implement functions for:
#  - Querying student info
#  - adding new students
#  - calculating GPA metrics
#  - assigning academic violations
#  - quit program

# %%
print("\n Welcome to the Student Management System")

while True:
    print("\n Menu")
    print("1. Student Information Query")
    print("2. Student Information Entry")
    print("3. Query GPA Metrics")
    print("4. Academic Violations")
    print("5. Quit Program")

    selection = input("Select your option")

    if selection == "1":
        print("\n Student list:")
        for i in range(len(first_names)):
            print(f"{i+1}. {first_names[i]} {last_names[i]} | Major: {majors[i]} | GPA: {gpas[i]} | Violation: {student_violations[i]}")
        
    elif selection == "2":
        print("\n Add new student information")
        first_name = input("First name:")
        first_names.append(first_name)
        student_added = True
        last_name = input("Last name:")
        last_names.append(last_name)
        major = input("Major:")
        majors.append(major)
        gpa = input("GPA:")
        gpas.append(gpa)
        student_violations.append("None")

    elif selection == "3":
        print("\n Query GPA Metrics")
        gpas = [float(gpa) for gpa in gpas]
        max_gpa = max(gpas)
        print(f"Highest GPA: {max_gpa}")
        min_gpa = min(gpas)
        print(f"Lowest GPA: {min_gpa}")
        avg_gpa = (sum(gpas)/len(gpas))
        print(f"Average GPA: {avg_gpa}")

    elif selection == "4":
        print("\n Student list:")
        for i in range(len(first_names)):
            print(f"{i+1}. {first_names[i]} {last_names[i]}")

        student_index = int(input("Select a student by number:"))-1
        if 0 <= student_index <len(first_names):
            print("\n Select the violation:")
            for i, v in enumerate(academic_violations):
                print(f"{i+1}. {v}")

            violation_index = int(input("Enter academic violation by number")) -1
            if 0 <= violation_index < len(academic_violations):
                student_violations[student_index] = academic_violations[violation_index]
                print(f"{first_names[student_index]} {last_names[student_index]} has been marked for: {academic_violations[violation_index]}")
            else:
                print("Error. There is no violation by this number.")

        else:
            print("Invalid student number.")


    elif selection == "5":
        print("\n Program is shut down. Goodbye.")
        break

    else:
        print("\n Invalid selection. Please try again.")
# Out:
#  Welcome to the Student Management System
#
#  Menu
# 1. Student Information Query
# 2. Student Information Entry
# 3. Query GPA Metrics
# 4. Academic Violations
# 5. Quit Program
# Select your option 3
#  Query GPA Metrics
# Highest GPA: 3.9
# Lowest GPA: 3.0
# Average GPA: 3.525
#
#  Menu
# 1. Student Information Query
# 2. Student Information Entry
# 3. Query GPA Metrics
# 4. Academic Violations
# 5. Quit Program
# Select your option 1
#  Student list:
# 1. Carmen Berzatto | Major: Anthropology | GPA: 3.7 | Violation: none
# 2. Sydney Adamu | Major: History | GPA: 3.5 | Violation: none
# 3. Neil Fak | Major: Biology | GPA: 3.0 | Violation: none
# 4. Marcus Brooks | Major: Forestry | GPA: 3.9 | Violation: none
#
#  Menu
# 1. Student Information Query
# 2. Student Information Entry
# 3. Query GPA Metrics
# 4. Academic Violations
# 5. Quit Program
# Select your option 2
#  Add new student information
# First name: Magdalena
# Last name: Gerharter
# Major: MBA
# GPA: 4.0
#  Menu
# ...

# %% [markdown]
# ### Resources
#
# Week 6 Materials - Instructor-led Lab and Tutorial
# ChatGPT (see screenshots)
#
# > ![Screenshot 2025-04-03 004137.png](attachment:994a6b58-03d2-4c52-b61f-217c97b7e034.png)
# > ![Screenshot 2025-04-03 004248.png](attachment:834e8a21-31ac-48ed-a8be-12c90888b772.png)
# > ![Screenshot 2025-04-03 004307.png](attachment:eca66466-53aa-4dcb-886d-a47ac124689f.png)
# > ![Screenshot 2025-04-03 004330.png](attachment:feb28064-088a-4b5a-abf2-15c0062b8c39.png)
# > ![Screenshot 2025-04-03 004350.png](attachment:1adc1c73-d1f8-4567-bb04-06807d0ffb40.png)
# > ![Screenshot 2025-04-03 004406.png](attachment:c8a8a022-81a1-404f-9aec-3351d4a5264b.png)
# > ![Screenshot 2025-04-03 004421.png](attachment:aefb7fbe-0bb2-40f4-9509-9ed04903cee6.png)
# > ![Screenshot 2025-04-03 004819.png](attachment:2c94ad2d-a169-4fd8-8623-70f3dd3041ac.png)
# > ![Screenshot 2025-04-03 004832.png](attachment:cc742b94-06f0-48c9-9b77-9eee2466c23b.png)
# > ![Screenshot 2025-04-03 004851.png](attachment:01a9db44-8a2a-4329-846d-8a12dcdaf457.png)
# > ![Screenshot 2025-04-03 004909.png](attachment:716d25a1-2083-4d62-a34b-d203afc89192.png)
# > ![Screenshot 2025-04-03 004928.png](attachment:873e4002-c7f5-4064-acd1-58da05ca1d0d.png)
# > ![Screenshot 2025-04-03 005013.png](attachment:aa4f3617-cb76-4329-91f9-9803b2e4ffc2.png)
# > ![Screenshot 2025-04-03 005020.png](attachment:7141eebc-bd3e-4809-a40f-203ff0783551.png)
